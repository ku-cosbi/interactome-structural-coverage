# %%
library(UpSetR)
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   1.0.1
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Interactome

# %%
all_raw <- readxl::read_excel('processed_data/interactomes/upset_ready/upset_all_raw.xlsx')
pdb <- readxl::read_excel('processed_data/interactomes/upset_ready/upset_pdb.xlsx')
homology <- readxl::read_excel('processed_data/interactomes/upset_ready/upset_homology.xlsx')
af_85 <- readxl::read_excel('processed_data/interactomes/upset_ready/upset_af_85.xlsx')

# %%
UpSetR::upset(as.data.frame(all_raw), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Protein-Protein Interactions", sets.x.label = "PPIs per Database", 
              text.scale = c(2, 2, 1.9, 1.6, 2, 1.3))
# Out:
# plot without title

# %%
UpSetR::upset(as.data.frame(pdb), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Protein-Protein Interactions", sets.x.label = "PPIs per Database", 
              text.scale = c(1.7, 1.5, 1.5, 1.3, 1.7, 1.5))
# Out:
# plot without title

# %%
UpSetR::upset(as.data.frame(homology), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Protein-Protein Interactions", sets.x.label = "PPIs per Database", 
              text.scale = c(1.7, 1.5, 1.5, 1.3, 1.7, 1.5))
# Out:
# plot without title

# %% [markdown]
# ## Save

# %%
png(file="figures/interactome/all_upset.png", units="in", width=11, height=5, res=700)
UpSetR::upset(as.data.frame(all_raw), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Protein-Protein Interactions", sets.x.label = "PPIs per Database", 
              text.scale = c(2.3, 2.5, 2, 1.8, 2.3, 2))
dev.off()
# Out:
# png
#   2

# %%
png(file="figures/interactome/homology_upset.png", units="in", width=11, height=5, res=700)
UpSetR::upset(as.data.frame(homology), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Protein-Protein Interactions", sets.x.label = "PPIs per Database", 
              text.scale = c(2.3, 2.5, 2, 1.8, 2.3, 2))
dev.off()
# Out:
# png
#   2

# %%
png(file="figures/interactome/pdb_upset.png", units="in", width=11, height=5, res=700)
UpSetR::upset(as.data.frame(pdb), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Protein-Protein Interactions", sets.x.label = "PPIs per Database", 
              text.scale = c(2.3, 2.5, 2, 1.8, 2.3, 2))
dev.off()
# Out:
# png
#   2

# %%
png(file="figures/interactome/af85_upset.png", units="in", width=11, height=5, res=700)
UpSetR::upset(as.data.frame(af_85), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Protein-Protein Interactions", sets.x.label = "PPIs per Database", 
              text.scale = c(2.3, 2.5, 2, 1.8, 2.3, 2))
dev.off()
# Out:
# png
#   2

# %% [markdown]
# # Proteome

# %%
proteome <- readxl::read_excel('processed_data/upset_proteome.xlsx')

# %%
png(file="figures/proteome/upset.png", units="in", width=11, height=5, res=700)
UpSetR::upset(as.data.frame(proteome), number.angles = 30, point.size = 2.5, line.size = 1, 
              main.bar.color = "#212C58",
              sets.bar.color = "#FC7869",
              mainbar.y.label = "Number of Proteins", sets.x.label = "Proteins per Database", 
              text.scale = c(2.3, 2.5, 2, 1.8, 2.3, 2))
dev.off()
# Out:
# png
#   2
